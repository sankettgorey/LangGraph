# %%
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import HumanMessage, AIMessage, BaseMessage
from chains import generation_chain, relfection_chain  # fixed typo here
from langchain_ollama import ChatOllama
from typing import TypedDict, List

llm = ChatOllama(model='qwen2.5:7b-instruct')

class Data(TypedDict):
    messages: List[BaseMessage]

def generation_node(state: Data):
    response = generation_chain.invoke({'messages': state['messages']})
    modified_state = {'messages': state['messages'] + [AIMessage(content=response.content)]}
    print("Generation Node State:", modified_state)
    return modified_state

def reflection_node(state: Data):
    response = relfection_chain.invoke({'messages': state['messages']})
    print('*' * 10)
    print("Reflection response:", response)
    new_state = {'messages': state['messages'] + [HumanMessage(content=response.content)]}
    return new_state

generate = 'GENERATE'
reflect = 'REFLECT'

def shall_continue(state: Data):
    if len(state['messages']) > 6:
        return END
    return reflect  # correctly returning next node key for conditional edge

graph = StateGraph(Data)
graph.add_node(generate, generation_node)
graph.add_node(reflect, reflection_node)
graph.set_entry_point(generate)

graph.add_conditional_edges(generate, shall_continue)  # controls whether to end or go to reflect
graph.add_edge(reflect, generate)  # after reflection, go back to generate

workflow = graph.compile()

# %%
initial_state = {'messages': [HumanMessage(content='generate a tweet on advantages of ai')]}

final_state = workflow.invoke(initial_state)

print(final_state['messages'][-1].content)

print()
print()

final_state
# Out:
# Generation Node State: {'messages': [HumanMessage(content='generate a tweet on advantages of ai', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Exciting news! 🚀 Artificial Intelligence (AI) is revolutionizing our world in countless ways! From streamlining processes to enhancing creativity, here are just a few advantages:\n\n📈 Increased Efficiency: AI automates routine tasks, saving time and reducing human error.\n🧠 Enhanced Decision Making: AI analyzes vast data sets to provide insights that boost business outcomes.\n💡 Creativity Boost: AI tools help in generating innovative ideas and solutions across industries.\n\nReady to explore how AI can transform your world? 🌐 #AIAdvantages #TechInnovation', additional_kwargs={}, response_metadata={})]}
# **********
# Reflection response: content=' #FutureIsNow\n\nGrade: 6/10\n\nRecommendations:\n- **Length**: Good, but consider adding a call-to-action or a personal story to make it more engaging.\n- **Virality**: Improved by including relevant hashtags and possibly an eye-catching image or GIF that illustrates AI in action.\n- **Style**: The tone is informative, but you could inject a bit of enthusiasm to engage the audience better. For instance, start with a bold statement or a question to grab attention.\n\nTry expanding on one specific advantage for deeper engagement, like this:\n\n💡 Did you know? AI can revolutionize healthcare by predicting diseases before they manifest! Imagine personalized treatments tailored just for you. 🌟 #AIInHealthcare\n\nThis version adds a specific example and a direct benefit, which can make the tweet more impactful and shareable.' additional_kwargs={} response_metadata={'model': 'qwen2.5:7b-instruct', 'created_at': '2025-10-22T17:59:33.8789576Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4257617200, 'load_duration': 212321900, 'prompt_eval_count': 166, 'prompt_eval_duration': 85462800, 'eval_count': 171, 'eval_duration': 3290305400, 'model_name': 'qwen2.5:7b-instruct'} id='run--aa046306-aa3e-4f54-af69-483f8d0b7038-0' usage_metadata={'input_tokens': 166, 'output_tokens': 171, 'total_tokens': 337}
# Generation Node State: {'messages': [HumanMessage(content='generate a tweet on advantages of ai', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Exciting news! 🚀 Artificial Intelligence (AI) is revolutionizing our world in countless ways! From streamlining processes to enhancing creativity, here are just a few advantages:\n\n📈 Increased Efficiency: AI automates routine tasks, saving time and reducing human error.\n🧠 Enhanced Decision Making: AI analyzes vast data sets to provide insights that boost business outcomes.\n💡 Creativity Boost: AI tools help in generating innovative ideas and solutions across industries.\n\nReady to explore how AI can transform your world? 🌐 #AIAdvantages #TechInnovation', additional_kwargs={}, response_metadata={}), HumanMessage(content=' #FutureIsNow\n\nGrade: 6/10\n\nRecommendations:\n- **Length**: Good, but consider adding a call-to-action or a personal story to make it more engaging.\n- **Virality**: Improved by including relevant hashtags and possibly an eye-catching image or GIF that illustrates AI in action.\n- **Style**: The tone is informative, but you could inject a bit of enthusiasm to engage the audience better. For instance, start with a bold statement or a question to grab attention.\n\nTry expanding on one specific advantage for deeper engagement, like this:\n\n💡 Did you know? AI can revolutionize healthcare by predicting diseases before they manifest! Imagine personalized treatments tailored just for you. 🌟 #AIInHealthcare\n\nThis version adds a specific example and a direct benefit, which can make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Did you know? AI is revolutionizing healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 #FutureIsNow #AIInHealthcare\n\nThis version starts with a bold statement, adds a specific example, includes a direct benefit, and uses relevant hashtags to make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={})]}
# **********
# Reflection response: content=' Here’s a detailed breakdown of the recommendations:\n\n### Grading: 8/10\n- **Length**: The tweet is concise yet informative, making it easy to read and share.\n- **Virality**: Hashtags are included (e.g., #FutureIsNow, #AIInHealthcare), which can help increase visibility. Adding an eye-catching image or GIF could further enhance virality by making the tweet more visually appealing.\n- **Style**: The tone is enthusiastic with a bold opening statement and a compelling example. A question at the end could engage readers more effectively.\n\n### Recommendations:\n1. **Length**:\n   - Maintain the brevity but consider adding a call-to-action or personal anecdote to make it more engaging. For instance: \n     💡 Did you know? AI can revolutionize healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\n2. **Virality**:\n   - Include relevant and popular hashtags to increase reach.\n   - Add an eye-catching image or GIF that illustrates AI in action, such as a medical diagnosis tool or a futuristic healthcare scenario.\n\n3. **Style**:\n   - Start with a strong statement to grab attention: \n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟\n   - Use rhetorical questions or direct statements to engage the audience, such as:\n     Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n   - Maintain an enthusiastic tone throughout.\n\nBy implementing these suggestions, your tweet will be more engaging, shareable, and impactful.' additional_kwargs={} response_metadata={'model': 'qwen2.5:7b-instruct', 'created_at': '2025-10-22T17:59:44.5968778Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8662967800, 'load_duration': 201797100, 'prompt_eval_count': 418, 'prompt_eval_duration': 202758000, 'eval_count': 360, 'eval_duration': 7209076000, 'model_name': 'qwen2.5:7b-instruct'} id='run--7e8533c8-699a-489a-83f3-4f743b414c7a-0' usage_metadata={'input_tokens': 418, 'output_tokens': 360, 'total_tokens': 778}
# Generation Node State: {'messages': [HumanMessage(content='generate a tweet on advantages of ai', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Exciting news! 🚀 Artificial Intelligence (AI) is revolutionizing our world in countless ways! From streamlining processes to enhancing creativity, here are just a few advantages:\n\n📈 Increased Efficiency: AI automates routine tasks, saving time and reducing human error.\n🧠 Enhanced Decision Making: AI analyzes vast data sets to provide insights that boost business outcomes.\n💡 Creativity Boost: AI tools help in generating innovative ideas and solutions across industries.\n\nReady to explore how AI can transform your world? 🌐 #AIAdvantages #TechInnovation', additional_kwargs={}, response_metadata={}), HumanMessage(content=' #FutureIsNow\n\nGrade: 6/10\n\nRecommendations:\n- **Length**: Good, but consider adding a call-to-action or a personal story to make it more engaging.\n- **Virality**: Improved by including relevant hashtags and possibly an eye-catching image or GIF that illustrates AI in action.\n- **Style**: The tone is informative, but you could inject a bit of enthusiasm to engage the audience better. For instance, start with a bold statement or a question to grab attention.\n\nTry expanding on one specific advantage for deeper engagement, like this:\n\n💡 Did you know? AI can revolutionize healthcare by predicting diseases before they manifest! Imagine personalized treatments tailored just for you. 🌟 #AIInHealthcare\n\nThis version adds a specific example and a direct benefit, which can make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Did you know? AI is revolutionizing healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 #FutureIsNow #AIInHealthcare\n\nThis version starts with a bold statement, adds a specific example, includes a direct benefit, and uses relevant hashtags to make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}), HumanMessage(content=' Here’s a detailed breakdown of the recommendations:\n\n### Grading: 8/10\n- **Length**: The tweet is concise yet informative, making it easy to read and share.\n- **Virality**: Hashtags are included (e.g., #FutureIsNow, #AIInHealthcare), which can help increase visibility. Adding an eye-catching image or GIF could further enhance virality by making the tweet more visually appealing.\n- **Style**: The tone is enthusiastic with a bold opening statement and a compelling example. A question at the end could engage readers more effectively.\n\n### Recommendations:\n1. **Length**:\n   - Maintain the brevity but consider adding a call-to-action or personal anecdote to make it more engaging. For instance: \n     💡 Did you know? AI can revolutionize healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\n2. **Virality**:\n   - Include relevant and popular hashtags to increase reach.\n   - Add an eye-catching image or GIF that illustrates AI in action, such as a medical diagnosis tool or a futuristic healthcare scenario.\n\n3. **Style**:\n   - Start with a strong statement to grab attention: \n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟\n   - Use rhetorical questions or direct statements to engage the audience, such as:\n     Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n   - Maintain an enthusiastic tone throughout.\n\nBy implementing these suggestions, your tweet will be more engaging, shareable, and impactful.', additional_kwargs={}, response_metadata={}), AIMessage(content='💡 Did you know? AI is transforming the way we approach healthcar ...
# **********
# Reflection response: content=' Here’s a breakdown of the improvements:\n\n### Grading: 9/10\n- **Length**: Concise yet engaging with a call-to-action.\n- **Virality**: Hashtags and an eye-catching image/GIF can further enhance reach.\n- **Style**: Strong opening statement, rhetorical question for engagement, and enthusiastic tone.\n\n### Recommendations:\n1. **Length**:\n   - Maintain brevity but add a call-to-action: \n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟 Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n     Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\n2. **Virality**:\n   - Include relevant and popular hashtags: \n     #FutureIsNow, #AIInHealthcare\n   - Add an eye-catching image or GIF that illustrates AI in action, such as a medical diagnosis tool or a futuristic healthcare scenario.\n\n3. **Style**:\n   - Start with a strong statement to grab attention:\n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟\n   - Use rhetorical questions or direct statements to engage the audience:\n     Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n   - Maintain an enthusiastic tone throughout.\n\nBy following these recommendations, your tweet will be more engaging, shareable, and impactful.' additional_kwargs={} response_metadata={'model': 'qwen2.5:7b-instruct', 'created_at': '2025-10-22T17:59:55.4103061Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7936275600, 'load_duration': 195478400, 'prompt_eval_count': 884, 'prompt_eval_duration': 419062500, 'eval_count': 316, 'eval_duration': 6571721000, 'model_name': 'qwen2.5:7b-instruct'} id='run--6b36bd90-1f72-4d2f-ad55-444c665f07b8-0' usage_metadata={'input_tokens': 884, 'output_tokens': 316, 'total_tokens': 1200}
# Generation Node State: {'messages': [HumanMessage(content='generate a tweet on advantages of ai', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Exciting news! 🚀 Artificial Intelligence (AI) is revolutionizing our world in countless ways! From streamlining processes to enhancing creativity, here are just a few advantages:\n\n📈 Increased Efficiency: AI automates routine tasks, saving time and reducing human error.\n🧠 Enhanced Decision Making: AI analyzes vast data sets to provide insights that boost business outcomes.\n💡 Creativity Boost: AI tools help in generating innovative ideas and solutions across industries.\n\nReady to explore how AI can transform your world? 🌐 #AIAdvantages #TechInnovation', additional_kwargs={}, response_metadata={}), HumanMessage(content=' #FutureIsNow\n\nGrade: 6/10\n\nRecommendations:\n- **Length**: Good, but consider adding a call-to-action or a personal story to make it more engaging.\n- **Virality**: Improved by including relevant hashtags and possibly an eye-catching image or GIF that illustrates AI in action.\n- **Style**: The tone is informative, but you could inject a bit of enthusiasm to engage the audience better. For instance, start with a bold statement or a question to grab attention.\n\nTry expanding on one specific advantage for deeper engagement, like this:\n\n💡 Did you know? AI can revolutionize healthcare by predicting diseases before they manifest! Imagine personalized treatments tailored just for you. 🌟 #AIInHealthcare\n\nThis version adds a specific example and a direct benefit, which can make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}), AIMessage(content='🚀 Did you know? AI is revolutionizing healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 #FutureIsNow #AIInHealthcare\n\nThis version starts with a bold statement, adds a specific example, includes a direct benefit, and uses relevant hashtags to make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}), HumanMessage(content=' Here’s a detailed breakdown of the recommendations:\n\n### Grading: 8/10\n- **Length**: The tweet is concise yet informative, making it easy to read and share.\n- **Virality**: Hashtags are included (e.g., #FutureIsNow, #AIInHealthcare), which can help increase visibility. Adding an eye-catching image or GIF could further enhance virality by making the tweet more visually appealing.\n- **Style**: The tone is enthusiastic with a bold opening statement and a compelling example. A question at the end could engage readers more effectively.\n\n### Recommendations:\n1. **Length**:\n   - Maintain the brevity but consider adding a call-to-action or personal anecdote to make it more engaging. For instance: \n     💡 Did you know? AI can revolutionize healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\n2. **Virality**:\n   - Include relevant and popular hashtags to increase reach.\n   - Add an eye-catching image or GIF that illustrates AI in action, such as a medical diagnosis tool or a futuristic healthcare scenario.\n\n3. **Style**:\n   - Start with a strong statement to grab attention: \n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟\n   - Use rhetorical questions or direct statements to engage the audience, such as:\n     Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n   - Maintain an enthusiastic tone throughout.\n\nBy implementing these suggestions, your tweet will be more engaging, shareable, and impactful.', additional_kwargs={}, response_metadata={}), AIMessage(content='💡 Did you know? AI is transforming the way we approach healthcar ...
# 💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟 Imagine personalized treatments tailored just for you. How does this change your view on health tech?
#
# Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare
#
# This version maintains brevity, includes a call-to-action, and uses relevant hashtags to enhance virality. The strong opening statement and rhetorical question are designed to engage the audience effectively.
# {'messages': [HumanMessage(content='generate a tweet on advantages of ai', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='🚀 Exciting news! 🚀 Artificial Intelligence (AI) is revolutionizing our world in countless ways! From streamlining processes to enhancing creativity, here are just a few advantages:\n\n📈 Increased Efficiency: AI automates routine tasks, saving time and reducing human error.\n🧠 Enhanced Decision Making: AI analyzes vast data sets to provide insights that boost business outcomes.\n💡 Creativity Boost: AI tools help in generating innovative ideas and solutions across industries.\n\nReady to explore how AI can transform your world? 🌐 #AIAdvantages #TechInnovation', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content=' #FutureIsNow\n\nGrade: 6/10\n\nRecommendations:\n- **Length**: Good, but consider adding a call-to-action or a personal story to make it more engaging.\n- **Virality**: Improved by including relevant hashtags and possibly an eye-catching image or GIF that illustrates AI in action.\n- **Style**: The tone is informative, but you could inject a bit of enthusiasm to engage the audience better. For instance, start with a bold statement or a question to grab attention.\n\nTry expanding on one specific advantage for deeper engagement, like this:\n\n💡 Did you know? AI can revolutionize healthcare by predicting diseases before they manifest! Imagine personalized treatments tailored just for you. 🌟 #AIInHealthcare\n\nThis version adds a specific example and a direct benefit, which can make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='🚀 Did you know? AI is revolutionizing healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 #FutureIsNow #AIInHealthcare\n\nThis version starts with a bold statement, adds a specific example, includes a direct benefit, and uses relevant hashtags to make the tweet more impactful and shareable.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content=' Here’s a detailed breakdown of the recommendations:\n\n### Grading: 8/10\n- **Length**: The tweet is concise yet informative, making it easy to read and share.\n- **Virality**: Hashtags are included (e.g., #FutureIsNow, #AIInHealthcare), which can help increase visibility. Adding an eye-catching image or GIF could further enhance virality by making the tweet more visually appealing.\n- **Style**: The tone is enthusiastic with a bold opening statement and a compelling example. A question at the end could engage readers more effectively.\n\n### Recommendations:\n1. **Length**:\n   - Maintain the brevity but consider adding a call-to-action or personal anecdote to make it more engaging. For instance: \n     💡 Did you know? AI can revolutionize healthcare by predicting diseases before they even appear! Imagine receiving personalized treatments tailored specifically for you. 🌟 Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\n2. **Virality**:\n   - Include relevant and popular hashtags to increase reach.\n   - Add an eye-catching image or GIF that illustrates AI in action, such as a medical diagnosis tool or a futuristic healthcare scenario.\n\n3. **Style**:\n   - Start with a strong statement to grab attention: \n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟\n   - Use rhetorical questions or direct statements to engage the audience, such as:\n     Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n   - Maintain an enthusiastic tone throughout.\n\nBy implementing these suggestions, your tweet will be more engaging, shareable, and impactful.', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟 Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n\nShare how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\nThis version incorporates a strong opening statement, uses a rhetorical question to engage the audience, and includes a call-to-action. The hashtags are also included to increase visibility.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content=' Here’s a breakdown of the improvements:\n\n### Grading: 9/10\n- **Length**: Concise yet engaging with a call-to-action.\n- **Virality**: Hashtags and an eye-catching image/GIF can further enhance reach.\n- **Style**: Strong opening statement, rhetorical question for engagement, and enthusiastic tone.\n\n### Recommendations:\n1. **Length**:\n   - Maintain brevity but add a call-to-action: \n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟 Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n     Share how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\n2. **Virality**:\n   - Include relevant and popular hashtags: \n     #FutureIsNow, #AIInHealthcare\n   - Add an eye-catching image or GIF that illustrates AI in action, such as a medical diagnosis tool or a futuristic healthcare scenario.\n\n3. **Style**:\n   - Start with a strong statement to grab attention:\n     💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟\n   - Use rhetorical questions or direct statements to engage the audience:\n     Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n   - Maintain an enthusiastic tone throughout.\n\nBy following these recommendations, your tweet will be more engaging, shareable, and impactful.', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='💡 Did you know? AI is transforming the way we approach healthcare by predicting diseases before they even appear! 🌟 Imagine personalized treatments tailored just for you. How does this change your view on health tech?\n\nShare how AI is transforming your life in the comments below! #FutureIsNow #AIInHealthcare\n\nThis version maintains brevity, includes a call-to-action, and uses relevant hashtags to enhance virality. The strong opening statement and rhetorical question are designed to engage the audience effectively.', additional_kwargs={}, response_metadata={})]}
